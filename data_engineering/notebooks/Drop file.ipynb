-- %%
use catalog smart_odoo;
use schema bronze; -- Change between silver , bronze

truncate table load_tracking;

truncate table sale_order;
truncate table sale_order_line;
truncate table sale_order_template;
truncate table sale_order_template_line;
truncate table sale_mass_cancel_orders;

truncate table product_product;
truncate table product_template;
truncate table product_category;
truncate table product_combo;
truncate table product_combo_item;
truncate table product_pricelist;
truncate table product_pricelist_item;
truncate table product_tag;

truncate table purchase_order;
truncate table purchase_order_line;

truncate table stock_location;
truncate table stock_lot;
truncate table stock_move;
truncate table stock_move_line;
truncate table stock_picking;
truncate table stock_quant;
truncate table stock_route;
truncate table stock_rule;
truncate table stock_scrap;
truncate table stock_warehouse;
truncate table stock_warehouse_orderpoint;
truncate table stock_warn_insufficient_qty_scrap;

truncate table res_partner;
truncate table res_partner_category;
truncate table res_users;
truncate table res_groups;
truncate table res_company;

truncate table crm_lead;
truncate table crm_lost_reason;
truncate table crm_stage;
truncate table crm_team;

truncate table utm_campaign;
truncate table utm_medium;
truncate table utm_source;

truncate table account_account;
truncate table account_analytic_account;
truncate table account_analytic_line;
truncate table account_bank_statement;
truncate table account_bank_statement_line;
truncate table account_journal;
truncate table account_move;
truncate table account_move_line;
truncate table account_payment;
truncate table account_payment_term;
truncate table account_tax;
truncate table account_tax_group;
truncate table account_tax_repartition_line;

truncate table hr_department;
truncate table hr_employee;
truncate table hr_job;


-- truncate table sim_run_state;

-- %%
use catalog smart_odoo;
use schema gold;

truncate table dim_date;

truncate table dim_partner;
truncate table dim_user;

truncate table dim_product;
truncate table dim_product_combo;
truncate table dim_product_pricelist;

truncate table dim_account;
truncate table dim_journal;
truncate table dim_warehouse;
truncate table dim_inventory_location;

truncate table dim_campaign;
truncate table dim_lead;
truncate table dim_lost_reason;
truncate table dim_stage;
truncate table dim_team;

truncate table dim_department;
truncate table dim_employee;
truncate table dim_job;

truncate table fact_sales;

truncate table fact_purchase_order;

truncate table fact_crm_pipeline;


truncate table fact_gl_transactions;
truncate table fact_inventory_movement;
truncate table fact_inventory;
truncate table fact_invoice

-- %%
use catalog smart_odoo;
use schema silver; 

truncate table  stock_location;
truncate table  stock_lot;
truncate table  stock_move;
truncate table  stock_move_line;
truncate table  stock_picking;
truncate table  stock_quant;
truncate table  stock_scrap;
truncate table  stock_warehouse;
truncate table  stock_warehouse_orderpoint;

-- %%
use catalog smart_odoo;
use schema gold;

truncate table fact_inventory;
truncate table fact_inventory_movement;
drop table dim_inventory_location;
drop table dim_warehouse;

-- %%
use catalog smart_odoo;
use schema silver; -- Change between silver , bronze

truncate table  account_account;
truncate table  account_analytic_account;
truncate table  account_analytic_line;
truncate table  account_bank_statement;
truncate table  account_bank_statement_line;
truncate table  account_journal;
truncate table  account_move;
truncate table  account_move_line;
truncate table  account_payment;
truncate table  account_payment_term;
truncate table  account_tax;

-- %%
truncate table smart_odoo.gold.dim_account;
truncate table smart_odoo.gold.dim_journal;
truncate table smart_odoo.gold.fact_gl_transactions;
truncate table smart_odoo.gold.fact_invoice;
