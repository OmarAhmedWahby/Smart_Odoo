# %%
def get_secret(key):
    return dbutils.secrets.get("odoo_scope", key)

## Sensitive

ODOO_USER = get_secret("ODOO_USER")
ODOO_PASSWORD = get_secret("ODOO_PASSWORD")
ODOO_URL = get_secret("ODOO_URL")

## Config

ODOO_DB = "odoo_one"
CATALOG = "smart_odoo"
BRONZE_SCHEMA = "bronze"
TRACKING_TABLE = f"{CATALOG}.{BRONZE_SCHEMA}.load_tracking"
