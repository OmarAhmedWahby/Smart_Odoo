-- %%
USE CATALOG smart_odoo;

CREATE TABLE IF NOT EXISTS bronze.purchase_order
(
    id STRING,
    partner_id STRING,
    dest_address_id STRING,
    currency_id STRING,
    invoice_count STRING,
    fiscal_position_id STRING,
    payment_term_id STRING,
    incoterm_id STRING,
    user_id STRING,
    company_id STRING,
    reminder_date_before_receipt STRING,
    create_uid STRING,
    write_uid STRING,
    access_token STRING,
    name STRING,
    priority STRING,
    origin STRING,
    partner_ref STRING,
    state STRING,
    invoice_status STRING,
    note STRING,
    amount_untaxed STRING,
    amount_tax STRING,
    amount_total STRING,
    amount_total_cc STRING,
    currency_rate STRING,
    locked STRING,
    acknowledged STRING,
    receipt_reminder_email STRING,
    date_order TIMESTAMP,
    date_approve TIMESTAMP,
    date_planned TIMESTAMP,
    date_calendar_start STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
    picking_type_id STRING,
    incoterm_location STRING,
    receipt_status STRING,
    effective_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
use catalog smart_odoo;

CREATE TABLE IF NOT EXISTS bronze.purchase_order_line
(
    id STRING,

    sequence STRING,

    product_uom_id STRING,
    product_id STRING,
    order_id STRING,

    company_id STRING,
    partner_id STRING,

    create_uid STRING,
    write_uid STRING,

    qty_received_method STRING,
    display_type STRING,

    analytic_distribution STRING,
    name STRING,

    product_qty STRING,
    discount STRING,

    price_unit STRING,
    price_subtotal STRING,
    price_total STRING,

    qty_invoiced STRING,
    qty_received STRING,
    qty_received_manual STRING,
    qty_to_invoice STRING,

    is_downpayment STRING,

    date_planned TIMESTAMP,

    create_date TIMESTAMP,
    write_date TIMESTAMP,

    product_uom_qty STRING,
    price_tax STRING,
    technical_price_unit STRING,

    orderpoint_id STRING,
    location_final_id STRING,

    product_description_variants STRING,

    propagate_cancel STRING,

    sale_line_id STRING,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)
USING DELTA;
