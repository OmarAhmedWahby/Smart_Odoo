-- %%
USE CATALOG smart_odoo;

CREATE TABLE IF NOT EXISTS bronze.sale_order
(
    id STRING,
    campaign_id STRING,
    source_id STRING,
    medium_id STRING,
    company_id STRING,
    partner_id STRING,
    pending_email_template_id STRING,
    journal_id STRING,
    partner_invoice_id STRING,
    partner_shipping_id STRING,
    fiscal_position_id STRING,
    payment_term_id STRING,
    preferred_payment_method_line_id STRING,
    pricelist_id STRING,
    currency_id STRING,
    user_id STRING,
    team_id STRING,
    create_uid STRING,
    write_uid STRING,
    access_token STRING,
    name STRING,
    state STRING,
    client_order_ref STRING,
    origin STRING,
    reference STRING,
    signed_by STRING,
    invoice_status STRING,
    validity_date STRING,
    note STRING,
    currency_rate STRING,
    amount_untaxed STRING,
    amount_tax STRING,
    amount_total STRING,
    locked STRING,
    require_signature STRING,
    require_payment STRING,
    create_date TIMESTAMP,
    commitment_date TIMESTAMP,
    date_order TIMESTAMP,
    signed_on STRING,
    write_date TIMESTAMP,
    prepayment_percent STRING,
    sale_order_template_id STRING,
    customizable_pdf_form_fields STRING,
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

CREATE TABLE IF NOT EXISTS bronze.sale_order_line
(
    id STRING,
    order_id STRING,
    sequence STRING,
    company_id STRING,
    currency_id STRING,
    order_partner_id STRING,
    salesman_id STRING,
    product_id STRING,
    product_uom_id STRING,
    linked_line_id STRING,
    combo_item_id STRING,
    create_uid STRING,
    write_uid STRING,
    state STRING,
    display_type STRING,
    virtual_id STRING,
    linked_virtual_id STRING,
    qty_delivered_method STRING,
    invoice_status STRING,
    analytic_distribution STRING,
    extra_tax_data STRING,
    name STRING,
    product_uom_qty STRING,
    price_unit STRING,
    discount STRING,
    price_subtotal STRING,
    price_total STRING,
    price_reduce_taxexcl STRING,
    price_reduce_taxinc STRING,
    qty_delivered STRING,
    qty_invoiced STRING,
    qty_to_invoice STRING,
    untaxed_amount_invoiced STRING,
    untaxed_amount_to_invoice STRING,
    is_downpayment STRING,
    is_expense STRING,
    collapse_prices STRING,
    collapse_composition STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
    technical_price_unit STRING,
    price_tax STRING,
    customer_lead STRING,
    is_optional STRING,
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

CREATE TABLE IF NOT EXISTS bronze.sale_order_template
(
    id STRING,
    company_id STRING,
    sequence STRING,
    mail_template_id STRING,
    number_of_days STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    note STRING,
    journal_id STRING,
    active STRING,
    require_signature STRING,
    require_payment STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
    prepayment_percent STRING,
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
Select * from smart_odoo.bronze.sale_order

-- %%
USE CATALOG smart_odoo;

CREATE TABLE IF NOT EXISTS bronze.sale_order_template_line
(
    id STRING,
    sale_order_template_id STRING,
    sequence STRING,
    company_id STRING,
    product_id STRING,
    product_uom_id STRING,
    create_uid STRING,
    write_uid STRING,
    display_type STRING,
    name STRING,
    product_uom_qty STRING,
    is_optional STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

CREATE TABLE IF NOT EXISTS bronze.sale_mass_cancel_orders
(
    id STRING,
    create_uid STRING,
    write_uid STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;
