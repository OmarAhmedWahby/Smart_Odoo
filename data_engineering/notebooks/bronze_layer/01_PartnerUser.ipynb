-- %%
USE CATALOG smart_odoo;

CREATE TABLE IF NOT EXISTS bronze.res_partner
(
    id STRING,
    company_id STRING,
    create_date STRING,
    name STRING,
    parent_id STRING,
    user_id STRING,
    state_id STRING,
    country_id STRING,
    industry_id STRING,
    color STRING,
    commercial_partner_id STRING,
    create_uid STRING,
    write_uid STRING,
    complete_name STRING,
    ref STRING,
    lang STRING,
    tz STRING,
    vat STRING,
    company_registry STRING,
    website STRING,
    function STRING,
    type STRING,
    street STRING,
    street2 STRING,
    zip STRING,
    city STRING,
    email STRING,
    phone STRING,
    commercial_company_name STRING,
    company_name STRING,
    properties STRING,
    barcode STRING,
    comment STRING,
    partner_latitude STRING,
    partner_longitude STRING,
    active STRING,
    employee STRING,
    is_company STRING,
    partner_share STRING,
    write_date STRING,
    message_bounce STRING,
    email_normalized STRING,
    signup_type STRING,
    phone_sanitized STRING,
    specific_property_product_pricelist STRING,
    invoice_template_pdf_report_id STRING,
    supplier_rank STRING,
    customer_rank STRING,
    autopost_bills STRING,
    credit_limit STRING,
    property_account_payable_id STRING,
    property_account_receivable_id STRING,
    property_account_position_id STRING,
    property_payment_term_id STRING,
    property_supplier_payment_term_id STRING,
    trust STRING,
    ignore_abnormal_invoice_date STRING,
    ignore_abnormal_invoice_amount STRING,
    invoice_sending_method STRING,
    invoice_edi_format_store STRING,
    property_outbound_payment_method_line_id STRING,
    property_inbound_payment_method_line_id STRING,
    peppol_endpoint STRING,
    peppol_eas STRING,
    sale_warn_msg STRING,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-----------------------------------------------------

CREATE TABLE IF NOT EXISTS bronze.res_users
(
    id STRING,
    company_id STRING,
    partner_id STRING,
    active STRING,
    create_date STRING,
    login STRING,
    password STRING,
    action_id STRING,
    create_uid STRING,
    write_uid STRING,
    signature STRING,
    share STRING,
    write_date STRING,
    totp_last_counter STRING,
    totp_secret STRING,
    tour_enabled STRING,
    notification_type STRING,
    manual_im_status STRING,
    out_of_office_message STRING,
    out_of_office_from STRING,
    out_of_office_to STRING,
    odoobot_state STRING,
    odoobot_failed STRING,
    sale_team_id STRING,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-----------------------------------------------------

CREATE TABLE IF NOT EXISTS bronze.res_partner_category
(
    id STRING,
    color STRING,
    parent_id STRING,
    create_uid STRING,
    write_uid STRING,
    parent_path STRING,
    name STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-----------------------------------------------------

CREATE TABLE IF NOT EXISTS bronze.res_groups
(
    id STRING,
    name STRING,
    sequence STRING,
    privilege_id STRING,
    create_uid STRING,
    write_uid STRING,
    comment STRING,
    share STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
    api_key_duration STRING,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

CREATE TABLE IF NOT EXISTS bronze.res_company
(
    id STRING,
    name STRING,
    partner_id STRING,
    currency_id STRING,
    sequence STRING,

    create_date TIMESTAMP,

    parent_path STRING,
    parent_id STRING,
    paperformat_id STRING,
    external_report_layout_id STRING,
    create_uid STRING,
    write_uid STRING,
    email STRING,
    phone STRING,
    font STRING,
    primary_color STRING,
    secondary_color STRING,
    layout_background STRING,
    report_header STRING,
    report_footer STRING,
    company_details STRING,
    active STRING,
    uses_default_logo STRING,

    write_date TIMESTAMP,

    logo_web STRING,
    resource_calendar_id STRING,
    alias_domain_id STRING,
    email_primary_color STRING,
    email_secondary_color STRING,
    iap_enrich_auto_done STRING,
    snailmail_color STRING,
    snailmail_cover STRING,
    snailmail_duplex STRING,
    fiscalyear_last_day STRING,
    transfer_account_id STRING,
    default_cash_difference_income_account_id STRING,
    default_cash_difference_expense_account_id STRING,
    account_journal_suspense_account_id STRING,
    account_journal_early_pay_discount_gain_account_id STRING,
    account_journal_early_pay_discount_loss_account_id STRING,
    account_sale_tax_id STRING,
    account_purchase_tax_id STRING,
    account_purchase_receipt_fiscal_position_id STRING,
    currency_exchange_journal_id STRING,
    income_currency_exchange_account_id STRING,
    expense_currency_exchange_account_id STRING,
    incoterm_id STRING,
    batch_payment_sequence_id STRING,
    account_opening_move_id STRING,
    account_default_pos_receivable_account_id STRING,
    expense_accrual_account_id STRING,
    revenue_accrual_account_id STRING,
    automatic_entry_default_journal_id STRING,
    domestic_fiscal_position_id STRING,
    account_fiscal_country_id STRING,
    tax_cash_basis_journal_id STRING,
    account_cash_basis_base_account_id STRING,
    account_discount_income_allocation_id STRING,
    account_discount_expense_allocation_id STRING,
    income_account_id STRING,
    expense_account_id STRING,
    price_difference_account_id STRING,
    fiscalyear_last_month STRING,
    chart_template STRING,
    bank_account_code_prefix STRING,
    cash_account_code_prefix STRING,
    transfer_account_code_prefix STRING,
    tax_calculation_rounding_method STRING,
    terms_type STRING,
    quick_edit_mode STRING,
    account_price_include STRING,

    fiscalyear_lock_date TIMESTAMP,
    tax_lock_date TIMESTAMP,
    sale_lock_date TIMESTAMP,
    purchase_lock_date TIMESTAMP,
    hard_lock_date TIMESTAMP,
    account_opening_date TIMESTAMP,

    invoice_terms STRING,
    invoice_terms_html STRING,
    expects_chart_of_accounts STRING,
    anglo_saxon_accounting STRING,
    qr_code STRING,
    link_qr_code STRING,
    display_invoice_amount_total_words STRING,
    display_invoice_tax_company_currency STRING,
    account_use_credit_limit STRING,
    tax_exigibility STRING,
    account_storno STRING,
    restrictive_audit_trail STRING,
    autopost_bills STRING,
    quotation_validity_days STRING,
    sale_discount_product_id STRING,
    downpayment_account_id STRING,
    sale_onboarding_payment_method STRING,
    portal_confirmation_sign STRING,
    portal_confirmation_pay STRING,
    prepayment_percent STRING,
    sale_order_template_id STRING,
    nomenclature_id STRING,
    internal_transit_location_id STRING,
    stock_mail_confirmation_template_id STRING,
    annual_inventory_day STRING,
    annual_inventory_month STRING,
    stock_confirmation_type STRING,
    stock_move_email_validation STRING,
    stock_text_confirmation STRING,
    horizon_days STRING,
    account_stock_journal_id STRING,
    account_stock_valuation_id STRING,
    account_production_wip_account_id STRING,
    account_production_wip_overhead_account_id STRING,
    inventory_period STRING,
    inventory_valuation STRING,
    cost_method STRING,
    stock_sms_confirmation_template_id STRING,
    has_received_warning_stock_sms STRING,
    security_lead STRING,
    po_lock STRING,
    po_double_validation STRING,
    po_double_validation_amount STRING,
    days_to_purchase STRING,
    hr_presence_control_email_amount STRING,
    contract_expiration_notice_period STRING,
    work_permit_expiration_notice_period STRING,
    hr_presence_control_ip_list STRING,
    employee_properties_definition STRING,
    hr_presence_control_login STRING,
    hr_presence_control_email STRING,
    hr_presence_control_ip STRING,
    hr_presence_control_attendance STRING
)USING DELTA;
