-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_account (1)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_account
(
    id STRING,
    currency_id STRING,
    create_uid STRING,
    write_uid STRING,
    account_type STRING,
    name STRING,
    description STRING,
    code_store STRING,
    note STRING,
    active STRING,
    reconcile STRING,
    non_trade STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_analytic_account (2)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_analytic_account
(
    id STRING,
    plan_id STRING,
    root_plan_id STRING,
    company_id STRING,
    partner_id STRING,
    create_uid STRING,
    write_uid STRING,
    code STRING,
    name STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_analytic_line (3)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_analytic_line
(
    id STRING,
    account_id STRING,
    product_uom_id STRING,
    partner_id STRING,
    user_id STRING,
    company_id STRING,
    currency_id STRING,
    create_uid STRING,
    write_uid STRING,
    product_id STRING,
    general_account_id STRING,
    journal_id STRING,
    move_line_id STRING,
    x_plan2_id STRING,
    x_plan3_id STRING,
    so_line STRING,
    name STRING,
    category STRING,
    code STRING,
    ref STRING,
    date TIMESTAMP,
    amount STRING,
    unit_amount STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_bank_statement (5)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_bank_statement
(
    id STRING,
    company_id STRING,
    currency_id STRING,
    journal_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    reference STRING,
    first_line_index STRING,
    date TIMESTAMP,
    balance_start STRING,
    balance_end STRING,
    balance_end_real STRING,
    is_complete STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_bank_statement_line (6)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_bank_statement_line
(
    id STRING,
    move_id STRING,
    journal_id STRING,
    company_id STRING,
    statement_id STRING,
    sequence STRING,
    partner_id STRING,
    currency_id STRING,
    foreign_currency_id STRING,
    create_uid STRING,
    write_uid STRING,
    account_number STRING,
    partner_name STRING,
    transaction_type STRING,
    payment_ref STRING,
    internal_index STRING,
    transaction_details STRING,
    amount STRING,
    amount_currency STRING,
    amount_residual STRING,
    is_reconciled STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_move (7)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_move
(
    id STRING,
    sequence_number STRING,
    journal_id STRING,
    company_id STRING,
    origin_payment_id STRING,
    statement_line_id STRING,
    invoice_payment_term_id STRING,
    partner_id STRING,
    commercial_partner_id STRING,
    partner_shipping_id STRING,
    partner_bank_id STRING,
    fiscal_position_id STRING,
    currency_id STRING,
    reversed_entry_id STRING,
    invoice_user_id STRING,
    invoice_incoterm_id STRING,
    invoice_cash_rounding_id STRING,
    create_uid STRING,
    write_uid STRING,
    campaign_id STRING,
    source_id STRING,
    medium_id STRING,
    team_id STRING,
    sequence_prefix STRING,
    name STRING,
    ref STRING,
    state STRING,
    move_type STRING,
    auto_post STRING,
    payment_reference STRING,
    payment_state STRING,
    invoice_source_email STRING,
    invoice_partner_display_name STRING,
    invoice_origin STRING,
    incoterm_location STRING,
    narration STRING,
    date TIMESTAMP,
    auto_post_until TIMESTAMP,
    invoice_date TIMESTAMP,
    invoice_date_due TIMESTAMP,
    delivery_date TIMESTAMP,
    invoice_currency_rate STRING,
    amount_untaxed STRING,
    amount_tax STRING,
    amount_total STRING,
    amount_residual STRING,
    amount_untaxed_signed STRING,
    amount_tax_signed STRING,
    amount_total_signed STRING,
    amount_residual_signed STRING,
    always_tax_exigible STRING,
    checked STRING,
    posted_before STRING,
    is_move_sent STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_move_line (8)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_move_line
(
    id STRING,
    move_id STRING,
    journal_id STRING,
    company_id STRING,
    company_currency_id STRING,
    sequence STRING,
    account_id STRING,
    currency_id STRING,
    partner_id STRING,
    payment_id STRING,
    statement_line_id STRING,
    statement_id STRING,
    tax_line_id STRING,
    tax_group_id STRING,
    product_id STRING,
    product_uom_id STRING,
    create_uid STRING,
    write_uid STRING,
    move_name STRING,
    parent_state STRING,
    ref STRING,
    name STRING,
    display_type STRING,
    analytic_distribution STRING,
    date TIMESTAMP,
    invoice_date TIMESTAMP,
    date_maturity TIMESTAMP,
    debit STRING,
    credit STRING,
    balance STRING,
    amount_currency STRING,
    tax_base_amount STRING,
    amount_residual STRING,
    amount_residual_currency STRING,
    quantity STRING,
    price_unit STRING,
    price_subtotal STRING,
    price_total STRING,
    discount STRING,
    is_storno STRING,
    reconciled STRING,
    is_downpayment STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_journal (9)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_journal
(
    id STRING,
    default_account_id STRING,
    suspense_account_id STRING,
    sequence STRING,
    currency_id STRING,
    company_id STRING,
    bank_account_id STRING,
    create_uid STRING,
    write_uid STRING,
    code STRING,
    type STRING,
    invoice_reference_type STRING,
    invoice_reference_model STRING,
    bank_statements_source STRING,
    name STRING,
    active STRING,
    is_self_billing STRING,
    restrict_mode_hash_table STRING,
    refund_sequence STRING,
    payment_sequence STRING,
    show_on_dashboard STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_tax (10)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_tax
(
    id STRING,
    company_id STRING,
    sequence STRING,
    tax_group_id STRING,
    cash_basis_transition_account_id STRING,
    country_id STRING,
    create_uid STRING,
    write_uid STRING,
    type_tax_use STRING,
    tax_scope STRING,
    amount_type STRING,
    price_include_override STRING,
    tax_exigibility STRING,
    name STRING,
    description STRING,
    invoice_label STRING,
    amount STRING,
    ubl_cii_tax_category_code STRING,
    l10n_eg_eta_code STRING,
    is_domestic STRING,
    active STRING,
    include_base_amount STRING,
    is_base_affected STRING,
    analytic STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_tax_group (11)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_tax_group
(
    id STRING,
    sequence STRING,
    company_id STRING,
    tax_payable_account_id STRING,
    tax_receivable_account_id STRING,
    country_id STRING,
    create_uid STRING,
    write_uid STRING,
    pos_receipt_label STRING,
    name STRING,
    preceding_subtotal STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_tax_repartition_line (12)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_tax_repartition_line
(
    id STRING,
    account_id STRING,
    tax_id STRING,
    company_id STRING,
    sequence STRING,
    create_uid STRING,
    write_uid STRING,
    repartition_type STRING,
    document_type STRING,
    factor_percent STRING,
    use_in_tax_closing STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_tax_repartition_line (12)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_tax_repartition_line
(
    id STRING,
    account_id STRING,
    tax_id STRING,
    company_id STRING,
    sequence STRING,
    create_uid STRING,
    write_uid STRING,
    repartition_type STRING,
    document_type STRING,
    factor_percent STRING,
    use_in_tax_closing STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_payment (13)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.account_payment
(
    id STRING,
    move_id STRING,
    journal_id STRING,
    company_id STRING,
    partner_bank_id STRING,
    payment_method_line_id STRING,
    payment_method_id STRING,
    currency_id STRING,
    partner_id STRING,
    outstanding_account_id STRING,
    destination_account_id STRING,
    source_payment_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    state STRING,
    payment_type STRING,
    partner_type STRING,
    memo STRING,
    payment_reference STRING,
    date TIMESTAMP,
    amount STRING,
    amount_company_currency_signed STRING,
    is_reconciled STRING,
    is_matched STRING,
    is_sent STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.account_payment_term (14)
-- =====================================================

CREATE TABLE IF NOT EXISTS bronze.account_payment_term
(
    id STRING,
    company_id STRING,
    sequence STRING,
    discount_days STRING,
    create_uid STRING,
    write_uid STRING,
    early_pay_discount_computation STRING,
    name STRING,
    note STRING,
    active STRING,
    display_on_invoice STRING,
    early_discount STRING,
    discount_percentage STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,

    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);
