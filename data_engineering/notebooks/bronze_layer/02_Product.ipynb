-- %%
USE CATALOG smart_odoo;

-- Table: bronze.product_product (1)
CREATE TABLE IF NOT EXISTS bronze.product_product (
    id                                      STRING,
    product_tmpl_id                         STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    default_code                            STRING,
    barcode                                 STRING,
    combination_indices                     STRING,
    standard_price                          STRING,
    volume                                  STRING,
    weight                                  STRING,
    active                                  STRING,
    can_image_variant_1024_be_zoomed        STRING,
    is_favorite                             STRING,
    is_in_selected_section_of_order         STRING,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;


-- ============================================================

-- Table: bronze.product_template (2)
CREATE TABLE IF NOT EXISTS bronze.product_template (
    id                                      STRING,
    sequence                                STRING,
    categ_id                                STRING,
    uom_id                                  STRING,
    company_id                              STRING,
    color                                   STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    type                                    STRING,
    service_tracking                        STRING,
    default_code                            STRING,
    name                                    STRING,
    description                             STRING,
    description_purchase                    STRING,
    description_sale                        STRING,
    product_properties                      STRING,
    list_price                              STRING,
    volume                                  STRING,
    weight                                  STRING,
    sale_ok                                 STRING,
    purchase_ok                             STRING,
    active                                  STRING,
    can_image_1024_be_zoomed                STRING,
    has_configurable_attributes             STRING,
    is_favorite                             STRING,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    property_account_income_id              STRING,
    property_account_expense_id             STRING,
    service_type                            STRING,
    expense_policy                          STRING,
    invoice_policy                          STRING,
    sale_line_warn_msg                      STRING,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;


-- ============================================================

-- Table: bronze.product_category (3)
CREATE TABLE IF NOT EXISTS bronze.product_category (
    id                                      STRING,
    parent_id                               STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    name                                    STRING,
    complete_name                           STRING,
    parent_path                             STRING,
    product_properties_definition           STRING,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    property_account_income_categ_id        STRING,
    property_account_expense_categ_id       STRING,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- Table: bronze.product_combo (4)
CREATE TABLE IF NOT EXISTS bronze.product_combo (
    id                                      STRING,
    sequence                                STRING,
    company_id                              STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    name                                    STRING,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;


-- ============================================================

-- Table: bronze.product_combo_item (5)
CREATE TABLE IF NOT EXISTS bronze.product_combo_item (
    id                                      STRING,
    company_id                              STRING,
    combo_id                                STRING,
    product_id                              STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    extra_price                             STRING,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- Table: bronze.product_pricelist (6)
CREATE TABLE IF NOT EXISTS bronze.product_pricelist (
    id                                      STRING,
    sequence                                STRING,
    currency_id                             STRING,
    company_id                              STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    name                                    STRING,
    active                                  STRING,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;


-- ============================================================

-- Table: bronze.product_pricelist_item (7)
CREATE TABLE IF NOT EXISTS bronze.product_pricelist_item (
    id                                      STRING,
    pricelist_id                            STRING,
    company_id                              STRING,
    currency_id                             STRING,
    categ_id                                STRING,
    product_tmpl_id                         STRING,
    product_id                              STRING,
    base_pricelist_id                       STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    applied_on                              STRING,
    display_applied_on                      STRING,
    base                                    STRING,
    compute_price                           STRING,
    min_quantity                            STRING,
    fixed_price                             STRING,
    price_discount                          STRING,
    price_round                             STRING,
    price_surcharge                         STRING,
    price_markup                            STRING,
    price_min_margin                        STRING,
    price_max_margin                        STRING,
    date_start                              TIMESTAMP,
    date_end                                TIMESTAMP,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    percent_price                           STRING,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;


-- ============================================================

-- Table: bronze.product_tag (8)
CREATE TABLE IF NOT EXISTS bronze.product_tag (
    id                                      STRING,
    sequence                                STRING,
    create_uid                              STRING,
    write_uid                               STRING,
    color                                   STRING,
    name                                    STRING,
    visible_to_customers                    STRING,
    create_date                             TIMESTAMP,
    write_date                              TIMESTAMP,
    dwh_loaded_at                           TIMESTAMP,
    dwh_source_db                           STRING
)
USING DELTA;
