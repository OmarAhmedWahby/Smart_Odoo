-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.crm_lead (1)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.crm_lead
(
    id STRING,
    campaign_id STRING,
    source_id STRING,
    medium_id STRING,
    message_bounce STRING,
    user_id STRING,
    team_id STRING,
    company_id STRING,
    stage_id STRING,
    color STRING,
    recurring_plan STRING,
    partner_id STRING,
    lang_id STRING,
    state_id STRING,
    country_id STRING,
    lost_reason_id STRING,
    create_uid STRING,
    write_uid STRING,
    phone_sanitized STRING,
    email_normalized STRING,
    email_cc STRING,
    name STRING,
    referred STRING,
    type STRING,
    priority STRING,
    contact_name STRING,
    partner_name STRING,
    function STRING,
    email_from STRING,
    email_domain_criterion STRING,
    phone STRING,
    phone_state STRING,
    email_state STRING,
    website STRING,
    street STRING,
    street2 STRING,
    zip STRING,
    city STRING,
    won_status STRING,
    date_deadline STRING,
    lead_properties STRING,
    description STRING,
    expected_revenue STRING,
    prorated_revenue STRING,
    recurring_revenue STRING,
    recurring_revenue_monthly STRING,
    recurring_revenue_monthly_prorated STRING,
    recurring_revenue_prorated STRING,
    active STRING,
    date_closed TIMESTAMP,
    date_automation_last TIMESTAMP,
    date_open TIMESTAMP,
    date_last_stage_update TIMESTAMP,
    date_conversion TIMESTAMP,
    day_open STRING,
    day_close STRING,
    probability STRING,
    automated_probability STRING,
    reveal_id STRING,
    iap_enrich_done STRING,
    lead_mining_request_id STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.crm_stage (2)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.crm_stage
(
    id STRING,
    sequence STRING,
    rotting_threshold_days STRING,
    color STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    requirements STRING,
    is_won STRING,
    fold STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.crm_team (3)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.crm_team
(
    id STRING,
    sequence STRING,
    company_id STRING,
    user_id STRING,
    color STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    active STRING,
    invoiced_target STRING,
    alias_id STRING,
    assignment_domain STRING,
    lead_properties_definition STRING,
    use_leads STRING,
    use_opportunities STRING,
    assignment_optout STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.crm_lost_reason (4)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.crm_lost_reason
(
    id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.utm_campaign (5)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.utm_campaign
(
    id STRING,
    user_id STRING,
    stage_id STRING,
    color STRING,
    create_uid STRING,
    write_uid STRING,
    company_id STRING,
    name STRING,
    title STRING,
    active STRING,
    is_auto_campaign STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.utm_source (6)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.utm_source
(
    id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.utm_medium (7)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.utm_medium
(
    id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;
