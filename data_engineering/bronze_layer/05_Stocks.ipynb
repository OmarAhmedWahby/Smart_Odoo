-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.stock_move (1)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_move
(
    id STRING,
    sequence STRING,
    company_id STRING,
    product_id STRING,
    product_uom STRING,
    location_id STRING,
    location_dest_id STRING,
    location_final_id STRING,
    partner_id STRING,
    picking_id STRING,
    scrap_id STRING,
    rule_id STRING,
    picking_type_id STRING,
    origin_returned_move_id STRING,
    restrict_partner_id STRING,
    warehouse_id STRING,
    next_serial_count STRING,
    orderpoint_id STRING,
    packaging_uom_id STRING,
    create_uid STRING,
    write_uid STRING,
    priority STRING,
    state STRING,
    origin STRING,
    procure_method STRING,
    inventory_name STRING,
    reference STRING,
    next_serial STRING,
    reservation_date STRING,
    description_picking_manual STRING,
    product_qty STRING,
    product_uom_qty STRING,
    quantity STRING,
    picked STRING,
    propagate_cancel STRING,
    is_inventory STRING,
    additional STRING,
    date STRING,
    date_deadline TIMESTAMP,
    delay_alert_date STRING,
    price_unit STRING,
    packaging_uom_qty STRING,
    account_move_id STRING,
    value STRING,
    to_refund STRING,
    is_in STRING,
    is_out STRING,
    is_dropship STRING,
    sale_line_id STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_location (2)
-- =====================================================
CREATE TABLE IF NOT EXISTS bronze.stock_location
(
    id STRING,
    location_id STRING,
    company_id STRING,
    removal_strategy_id STRING,
    cyclic_inventory_frequency STRING,
    warehouse_id STRING,
    storage_category_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    complete_name STRING,
    usage STRING,
    parent_path STRING,
    barcode STRING,
    last_inventory_date TIMESTAMP,
    next_inventory_date TIMESTAMP,
    active STRING,
    replenish_location STRING,
    valuation_account_id STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_lot (3)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_lot
(
    id STRING,
    product_id STRING,
    company_id STRING,
    location_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    ref STRING,
    lot_properties STRING,
    note STRING,
    standard_price STRING,
    avg_cost STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_move_line (4)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_move_line
(
    id STRING,
    picking_id STRING,
    move_id STRING,
    company_id STRING,
    product_id STRING,
    product_uom_id STRING,
    package_id STRING,
    lot_id STRING,
    result_package_id STRING,
    package_history_id STRING,
    owner_id STRING,
    location_id STRING,
    location_dest_id STRING,
    create_uid STRING,
    write_uid STRING,
    lot_name STRING,
    state STRING,
    quantity STRING,
    quantity_product_uom STRING,
    picked STRING,
    is_entire_pack STRING,
    date STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_picking (5)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_picking
(
    id STRING,
    backorder_id STRING,
    return_id STRING,
    location_id STRING,
    location_dest_id STRING,
    picking_type_id STRING,
    partner_id STRING,
    company_id STRING,
    user_id STRING,
    owner_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    origin STRING,
    move_type STRING,
    state STRING,
    priority STRING,
    picking_properties STRING,
    note STRING,
    shipping_weight STRING,
    has_deadline_issue STRING,
    printed STRING,
    is_locked STRING,
    scheduled_date TIMESTAMP,
    date_deadline TIMESTAMP,
    date_done TIMESTAMP,
    sale_id STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_quant (6)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_quant
(
    id STRING,
    product_id STRING,
    company_id STRING,
    location_id STRING,
    lot_id STRING,
    package_id STRING,
    owner_id STRING,
    user_id STRING,
    create_uid STRING,
    write_uid STRING,
    inventory_date TIMESTAMP,
    quantity STRING,
    reserved_quantity STRING,
    inventory_quantity STRING,
    inventory_diff_quantity STRING,
    inventory_quantity_set STRING,
    in_date STRING,
    accounting_date TIMESTAMP,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_route (7)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_route
(
    id STRING,
    sequence STRING,
    supplied_wh_id STRING,
    supplier_wh_id STRING,
    company_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    active STRING,
    product_selectable STRING,
    product_categ_selectable STRING,
    warehouse_selectable STRING,
    package_type_selectable STRING,
    sale_selectable STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_rule (8)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_rule
(
    id STRING,
    sequence STRING,
    company_id STRING,
    location_dest_id STRING,
    location_src_id STRING,
    route_id STRING,
    route_sequence STRING,
    picking_type_id STRING,
    delay STRING,
    partner_address_id STRING,
    warehouse_id STRING,
    create_uid STRING,
    write_uid STRING,
    action STRING,
    procure_method STRING,
    auto STRING,
    push_domain STRING,
    name STRING,
    active STRING,
    location_dest_from_rule STRING,
    propagate_cancel STRING,
    propagate_carrier STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_warehouse (9)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_warehouse
(
    id STRING,
    company_id STRING,
    partner_id STRING,
    view_location_id STRING,
    lot_stock_id STRING,
    wh_input_stock_loc_id STRING,
    wh_qc_stock_loc_id STRING,
    wh_output_stock_loc_id STRING,
    wh_pack_stock_loc_id STRING,
    mto_pull_id STRING,
    pick_type_id STRING,
    pack_type_id STRING,
    out_type_id STRING,
    in_type_id STRING,
    int_type_id STRING,
    qc_type_id STRING,
    store_type_id STRING,
    xdock_type_id STRING,
    reception_route_id STRING,
    delivery_route_id STRING,
    sequence STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    code STRING,
    reception_steps STRING,
    delivery_steps STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_warehouse_orderpoint (10)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_warehouse_orderpoint
(
    id STRING,
    warehouse_id STRING,
    location_id STRING,
    product_id STRING,
    replenishment_uom_id STRING,
    company_id STRING,
    route_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    trigger STRING,
    snoozed_until STRING,
    deadline_date STRING,
    product_min_qty STRING,
    product_max_qty STRING,
    qty_to_order_computed STRING,
    qty_to_order_manual STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_scrap (11)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_scrap
(
    id STRING,
    company_id STRING,
    product_id STRING,
    product_uom_id STRING,
    lot_id STRING,
    package_id STRING,
    owner_id STRING,
    picking_id STRING,
    location_id STRING,
    scrap_location_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    origin STRING,
    state STRING,
    scrap_qty STRING,
    should_replenish STRING,
    date_done STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;

-- %%
USE CATALOG smart_odoo;

-- =====================================================
-- Table: bronze.stock_warn_insufficient_qty_scrap (12)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.stock_warn_insufficient_qty_scrap
(
    id STRING,
    product_id STRING,
    location_id STRING,
    scrap_id STRING,
    create_uid STRING,
    write_uid STRING,
    product_uom_name STRING,
    quantity STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
)USING DELTA;
