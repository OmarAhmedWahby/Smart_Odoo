-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.hr_employee (1)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.hr_employee
(
    id STRING,
    resource_id STRING,
    company_id STRING,
    message_main_attachment_id STRING,
    current_version_id STRING,
    user_id STRING,
    work_contact_id STRING,
    country_of_birth STRING,
    parent_id STRING,
    coach_id STRING,
    color STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    work_phone STRING,
    mobile_phone STRING,
    work_email STRING,
    legal_name STRING,
    private_phone STRING,
    private_email STRING,
    lang STRING,
    place_of_birth STRING,
    permit_no STRING,
    visa_no STRING,
    certificate STRING,
    study_field STRING,
    study_school STRING,
    emergency_contact STRING,
    emergency_phone STRING,
    barcode STRING,
    pin STRING,
    private_car_plate STRING,
    birthday TIMESTAMP,
    visa_expire TIMESTAMP,
    work_permit_expiration_date TIMESTAMP,
    salary_distribution STRING,
    employee_properties STRING,
    active STRING,
    birthday_public_display STRING,
    work_permit_scheduled_activity STRING,
    monday_location_id STRING,
    tuesday_location_id STRING,
    wednesday_location_id STRING,
    thursday_location_id STRING,
    friday_location_id STRING,
    saturday_location_id STRING,
    sunday_location_id STRING,
    today_location_name STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.hr_department (2)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.hr_department
(
    id STRING,
    company_id STRING,
    parent_id STRING,
    manager_id STRING,
    color STRING,
    master_department_id STRING,
    create_uid STRING,
    write_uid STRING,
    parent_path STRING,
    name STRING,
    note STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);

-- %%
USE CATALOG smart_odoo;
 
-- =====================================================
-- Table: bronze.hr_job (3)
-- =====================================================
 
CREATE TABLE IF NOT EXISTS bronze.hr_job
(
    id STRING,
    sequence STRING,
    no_of_recruitment STRING,
    user_id STRING,
    department_id STRING,
    company_id STRING,
    contract_type_id STRING,
    create_uid STRING,
    write_uid STRING,
    name STRING,
    description STRING,
    requirements STRING,
    active STRING,
    create_date TIMESTAMP,
    write_date TIMESTAMP,
 
    dwh_loaded_at TIMESTAMP,
    dwh_source_db STRING
);
