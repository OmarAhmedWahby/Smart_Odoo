# %%
def get_secret(key, default=None):
    try:
        return dbutils.secrets.get("odoo_scope", key)
    except:
        return default



ODOO_URL = "https://pastel-skittle-helium.ngrok-free.dev/jsonrpc"
ODOO_DB = "odoo_one"

ODOO_USER = get_secret("ODOO_USER", "omarwahby35@gmail.com")
ODOO_PASSWORD = get_secret("ODOO_PASSWORD", "Omar0151510050")

CATALOG = "smart_odoo"
BRONZE_SCHEMA = "bronze"
TRACKING_TABLE = f"{CATALOG}.{BRONZE_SCHEMA}.load_tracking"
